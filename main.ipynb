# %% [markdown]
# Parte 1 – Análisis exploratorio de datos

# %% [markdown]
# tumor es benigno o maligno.

# %% [markdown]
# Haga   una   exploración   rápida   de   sus   datos   para   eso   haga   un   resumen   de   su
# dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from quickda.clean_data import *

# %%
#lectura del data
datos = pd.read_csv("breast-cancer-wisconsin.data",index_col = 0)

# %%
datos.head()
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 1000025                                    1                  1
# 1002945                                    4                  5
# 1015425                                    1                  1
# 1016277                                    8                  1
# 1017023                                    1                  3
#
#                     Single Epithelial Cell Size Bare Nuclei  Bland Chromatin  \
# Sample code number
# ...

# %%
#mostrar la infomacion para conocer los tipos de datos que tiene
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1000025 to 897471
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              699 non-null    int64
#  1   Uniformity of Cell Size      699 non-null    int64
#  2   Uniformity of Cell Shape     699 non-null    int64
#  3   Marginal Adhesion            699 non-null    int64
#  4   Single Epithelial Cell Size  699 non-null    int64
#  5   Bare Nuclei                  699 non-null    object
#  6   Bland Chromatin              699 non-null    int64
#  7   Normal Nucleoli              699 non-null    int64
#  8   Mitoses                      699 non-null    int64
#  9   Class                        699 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 60.1+ KB

# %% [markdown]
# Diga   el   tipo   de   cada   una   de   las   variables   del   dataset   (cualitativa   o   categórica,
# cuantitativa continua, cuantitativa discreta)
#
#     La variable "Sample code number" parece ser una variable identificadora y no una variable que contenga información relevante para el análisis.
#
#     Las variables "Clump Thickness", "Uniformity of Cell Size", "Uniformity of Cell Shape", "Marginal Adhesion", "Single Epithelial Cell Size", "Bare Nuclei", "Bland Chromatin", "Normal Nucleoli" y "Mitoses" parecen ser variables cuantitativas discretas, ya que toman valores enteros.
#
#     La variable "Class" parece ser una variable categórica nominal, ya que toma solo dos valores posibles (2 y 4) que no tienen un orden natural entre ellos.

# %% [markdown]
# Incluya los gráficos exploratorios siendo consecuentes con el tipo de variable que
# están representando.

# %%
datos.columns
# Out:
# Index(['Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
# Gráfico de histograma para la variable "Clump Thickness"
sns.histplot(datos["Clump Thickness"])
plt.title("Distribución de Clump Thickness")
plt.xlabel("Clump Thickness")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Uniformity of Cell Size"
sns.histplot(datos["Uniformity of Cell Size"])
plt.title("Distribución de Uniformity of Cell Size")
plt.xlabel("Uniformity of Cell Size")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Uniformity of Cell Shape"
sns.histplot(datos["Uniformity of Cell Shape"])
plt.title("Distribución de Uniformity of Cell Shape")
plt.xlabel("Uniformity of Cell Shape")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Marginal Adhesion"
sns.histplot(datos["Marginal Adhesion"])
plt.title("Distribución de Marginal Adhesion")
plt.xlabel("Marginal Adhesion")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Uniformity of Cell Size"
sns.histplot(datos["Single Epithelial Cell Size"])
plt.title("Distribución de Single Epithelial Cell Size")
plt.xlabel("Single Epithelial Cell Size")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Bare Nuclei"
sns.histplot(datos["Bare Nuclei"])
plt.title("Distribución de Bare Nuclei")
plt.xlabel("Bare Nuclei")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Bland Chromatin"
sns.histplot(datos["Bland Chromatin"])
plt.title("Distribución de Bland Chromatin")
plt.xlabel("Bland Chromatin")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Normal Nucleoli"
sns.histplot(datos["Normal Nucleoli"])
plt.title("Distribución de Normal Nucleoli")
plt.xlabel("Normal Nucleoli")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Gráfico de histograma para la variable "Mitoses"
sns.histplot(datos["Mitoses"])
plt.title("Distribución de Mitoses")
plt.xlabel("Mitoses")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
sns.countplot(x=datos["Class"])
# Out:
# <AxesSubplot: xlabel='Class', ylabel='count'>

# %% [markdown]
# Aísle las variables numéricas de las categóricas, haga un análisis de correlación
# entre las mismas

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1000025 to 897471
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              699 non-null    int64
#  1   Uniformity of Cell Size      699 non-null    int64
#  2   Uniformity of Cell Shape     699 non-null    int64
#  3   Marginal Adhesion            699 non-null    int64
#  4   Single Epithelial Cell Size  699 non-null    int64
#  5   Bare Nuclei                  699 non-null    object
#  6   Bland Chromatin              699 non-null    int64
#  7   Normal Nucleoli              699 non-null    int64
#  8   Mitoses                      699 non-null    int64
#  9   Class                        699 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 60.1+ KB

# %%
# Seleccionar variables numéricas
numericas = datos.drop("Class", axis=1)

# Seleccionar variables categóricas
categoricas = datos["Class"]

# %%
correlacion = numericas.corr()
sns.heatmap(correlacion, cmap="YlGnBu")
plt.title("Matriz de correlación de variables numéricas")
plt.show()
# Out:
# C:\Users\omen\AppData\Local\Temp\ipykernel_29000\857730288.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Utilice   las  variables   categóricas,   haga   tablas  de   frecuencia,   proporción,   gráficas
# de barras o cualquier otra técnica que le permita explorar los datos

# %%
categorical_columns = ["Clump Thickness", "Uniformity of Cell Size", "Uniformity of Cell Shape", "Marginal Adhesion", 
                       "Single Epithelial Cell Size", "Bare Nuclei", "Bland Chromatin", "Normal Nucleoli"]

#mostrar los valores que son unicos para conocer los tipos que tiene
for col in categorical_columns:
    print(f"{col}: {datos[col].unique()}")
# Out:
# Clump Thickness: [ 5  3  6  4  8  1  2  7 10  9]
# Uniformity of Cell Size: [ 1  4  8 10  2  3  7  5  6  9]
# Uniformity of Cell Shape: [ 1  4  8 10  2  3  5  6  7  9]
# Marginal Adhesion: [ 1  5  3  8 10  4  6  2  9  7]
# Single Epithelial Cell Size: [ 2  7  3  1  6  4  5  8 10  9]
# Bare Nuclei: ['1' '10' '2' '4' '3' '9' '7' '?' '5' '8' '6']
# Bland Chromatin: [ 3  9  1  2  4  5  7  8  6 10]
# Normal Nucleoli: [ 1  2  7  4  5  3 10  6  9  8]

# %%
#observar la frecuencia que tiene cada elemento
for col in categorical_columns:
    print(f"Tabla de frecuencia para {col}:")
    display(datos[col].value_counts())
# Out:
# Tabla de frecuencia para Clump Thickness:
# 1     145
# 5     130
# 3     108
# 4      80
# 10     69
# 2      50
# 8      46
# 6      34
# 7      23
# 9      14
# Name: Clump Thickness, dtype: int64
# Tabla de frecuencia para Uniformity of Cell Size:
# 1     384
# 10     67
# 3      52
# 2      45
# 4      40
# 5      30
# 8      29
# 6      27
# 7      19
# 9       6
# Name: Uniformity of Cell Size, dtype: int64
# Tabla de frecuencia para Uniformity of Cell Shape:
# 1     353
# 2      59
# 10     58
# 3      56
# 4      44
# 5      34
# 6      30
# 7      30
# 8      28
# 9       7
# Name: Uniformity of Cell Shape, dtype: int64
# Tabla de frecuencia para Marginal Adhesion:
# 1     407
# 3      58
# 2      58
# 10     55
# 4      33
# 8      25
# 5      23
# 6      22
# 7      13
# 9       5
# Name: Marginal Adhesion, dtype: int64
# Tabla de frecuencia para Single Epithelial Cell Size:
# 2     386
# 3      72
# 4      48
# 1      47
# 6      41
# 5      39
# 10     31
# 8      21
# ...

# %%
for col in categorical_columns:
    plt.figure()
    sns.countplot(data=datos, x=col)
    plt.title(f"Frecuencia de {col}")
    plt.show()

# %% [markdown]
# Realice la limpieza de variables utilizando las técnicas vistas en clase, u otras que
# piense pueden ser de utilidad

# %% [markdown]
# En este caso la Bare Nuclei sale como si fura tipo obj por lo cual se pasara para que sea tipo numerica

# %%
datos['Bare Nuclei'] = pd.to_numeric(datos['Bare Nuclei'], errors='coerce')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1000025 to 897471
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              699 non-null    int64
#  1   Uniformity of Cell Size      699 non-null    int64
#  2   Uniformity of Cell Shape     699 non-null    int64
#  3   Marginal Adhesion            699 non-null    int64
#  4   Single Epithelial Cell Size  699 non-null    int64
#  5   Bare Nuclei                  683 non-null    float64
#  6   Bland Chromatin              699 non-null    int64
#  7   Normal Nucleoli              699 non-null    int64
#  8   Mitoses                      699 non-null    int64
#  9   Class                        699 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 60.1 KB

# %% [markdown]
# Verificar si hay valores faltantes en el conjunto de datos

# %%
datos.isnull().sum()
# Out:
# Clump Thickness                 0
# Uniformity of Cell Size         0
# Uniformity of Cell Shape        0
# Marginal Adhesion               0
# Single Epithelial Cell Size     0
# Bare Nuclei                    16
# Bland Chromatin                 0
# Normal Nucleoli                 0
# Mitoses                         0
# Class                           0
# dtype: int64

# %% [markdown]
# Reemplazar los datos faltantes de Bare Nuclei con sus medias de Bare Nuclei

# %%
datos['Bare Nuclei'].fillna(datos['Bare Nuclei'].mean(), inplace=True)

# %%
datos.isnull().sum()
# Out:
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
#estandarizar las columnas
datos = clean(datos, method = "standardize")

# %%
#eliminar filas dublicadas
datos = clean(datos, method = "duplicates")

# %%
#Eliminar filas faltantes
clean(datos, method = "dropmissing")
# Out:
#                     clump_thickness  uniformity_of_cell_size  \
# Sample code number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
# ...                             ...                      ...
# 763235                            3                        1
# 776715                            3                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     uniformity_of_cell_shape  marginal_adhesion  \
# Sample code number
# 1000025                                    1                  1
# ...

# %%
clean(datos, method="outliers", columns=[])
# Out:
# Empty DataFrame
# Columns: [clump_thickness, uniformity_of_cell_size, uniformity_of_cell_shape, marginal_adhesion, single_epithelial_cell_size, bare_nuclei, bland_chromatin, normal_nucleoli, mitoses, class]
# Index: []

# %%
datos.head()
# Out:
#                     clump_thickness  uniformity_of_cell_size  \
# Sample code number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
#
#                     uniformity_of_cell_shape  marginal_adhesion  \
# Sample code number
# 1000025                                    1                  1
# 1002945                                    4                  5
# 1015425                                    1                  1
# 1016277                                    8                  1
# 1017023                                    1                  3
#
#                     single_epithelial_cell_size  bare_nuclei  bland_chromatin  \
# Sample code number
# ...

# %%
#exportarlo a csv
datos.to_csv('limpieza.csv')
